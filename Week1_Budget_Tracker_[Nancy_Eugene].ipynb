# %% [markdown]
# <a href="https://colab.research.google.com/github/NancyEugene/ISYS2001LabTickets2026/blob/main/Week1_Budget_Tracker_%5BNancy_Eugene%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini Project 01: AI-Powered Budget Tracker
# # ISYS2001 Introduction to Business Programming
#
# **Instructions:**
# 1. Save a copy of this notebook to your Google Drive (File > Save a copy in Drive)
# 2. Rename it to include your name: `Week1_Budget_Tracker_[YourName]`
# 3. Complete all sections and code cells
# 4. Document your AI interactions as you go

# %% [markdown]
# ## Part 1: Environment Setup and First Steps

# %%
# Run this cell to test your environment
print("🎉 Welcome to ISYS2001: Introduction to Business Programming!")
print("📊 Project: Personal Finance Assistant")
print("🤖 Today's Goal: Build a Simple Budget Tracker with AI Help")

# Import datetime to timestamp your work
from datetime import datetime
print(f"\n📅 Worksheet started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# 🎉 Welcome to ISYS2001: Introduction to Business Programming!
# 📊 Project: Personal Finance Assistant
# 🤖 Today's Goal: Build a Simple Budget Tracker with AI Help
#
# 📅 Worksheet started at: 2026-02-25 11:56:22

# %% [markdown]
# ## Part 2: Your First AI Prompt
#
# Use an AI assistant (Gemini in Colab, ChatGPT, or GitHub Copilot) to create a program that:
# - Asks the user for their name
# - Asks for their monthly income
# - Prints a personalized welcome message
#
# ### 📝 Document Your AI Prompt Below:

# %%
# TASK: Write your AI prompt as a comment below
"""
My AI Prompt:
Using python create a program that:

Asks the user for their name
Asks for their monthly income
Prints a personalized welcome message
"""

# Paste the AI-generated code below:
# Ask the user for their name
name = input("Enter your name: ")

# Ask for their monthly income
income = input("Enter your monthly income: ")

# Convert income to a number (optional but useful)
income = float(income)

# Print a personalized welcome message
print("\nWelcome,", name + "!")
print("Your monthly income is", income)
print("Have a great day")
# Out:
# Enter your name: Nancy
# Enter your monthly income: 10000
#
# Welcome, Nancy!
# Your monthly income is 10000.0
# Have a great day

# %% [markdown]
# ### 🔍 Evidence Package Entry #1

# %%
from datetime import datetime

# Evidence Package Documentation
evidence_1 = {
    "timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    "context": "I wanted to create a simple input/output program to practice AI prompting for my name and monthly income.",
    "ai_tool_used": "ChatGPT",  # Update this
    "what_worked": "The AI understood my request and gave me a code that asks for and displays my name and monthly income.",
    "what_didnt": "I had to write the code without specific currency like MUR.",
    "what_i_learned": "I learned that variables like float help to store certain information in the memory."
}

# Display your evidence
print("📋 EVIDENCE PACKAGE #1")
for key, value in evidence_1.items():
    print(f"{key}: {value}")
# Out:
# 📋 EVIDENCE PACKAGE #1
# timestamp: 2026-02-25 19:01:00
# context: I wanted to create a simple input/output program to practice AI prompting for my name and monthly income.
# ai_tool_used: ChatGPT
# what_worked: The AI understood my request and gave me a code that asks for and displays my name and monthly income.
# what_didnt: I had to write the code without specific currency like MUR.
# what_i_learned: I learned that variables like float help to store certain information in the memory.

# %% [markdown]
# ## Part 3: Building the Budget Tracker
#
# Use AI to help you write a program that:
# - Allows users to input their monthly income
# - Allows users to input up to 3 expenses
# - Calculates remaining budget
# - Shows a warning if budget is negative
#
# ### 💡 Pro Tip: Be specific about requirements!

# %%
# TASK: Write your detailed prompt for the budget tracker
"""
My Budget Tracker Prompt:
Using python write a program that:

Allows users to input their monthly income
Allows users to input up to 3 expenses
Calculates remaining budget
Shows a warning if budget is negative
"""
# Out:
# '\nMy Budget Tracker Prompt:\nUsing python write a program that: \n\nAllows users to input their monthly income\nAllows users to input up to 3 expenses\nCalculates remaining budget\nShows a warning if budget is negative\n'

# %% [markdown]
# ### Paste and Test Your AI-Generated Budget Tracker

# %%
# AI-GENERATED BUDGET TRACKER CODE
# Ask for monthly income
income = float(input("Enter your monthly income: "))

# Ask for up to 3 expenses
expense1 = float(input("Enter expense 1: "))
expense2 = float(input("Enter expense 2: "))
expense3 = float(input("Enter expense 3: "))

# Calculate total expenses
total_expenses = expense1 + expense2 + expense3

# Calculate remaining budget
remaining_budget = income - total_expenses

# Display result
print("\nTotal expenses:", total_expenses)
print("Remaining budget:", remaining_budget)

# Warning if negative
if remaining_budget < 0:
    print("⚠ Warning: Your budget is negative! You are overspending.")
else:
    print("Good job! Your spending is within your budget.")
# Out:
# Enter your monthly income: 7000
# Enter expense 1: 3000
# Enter expense 2: 2000
# Enter expense 3: 4000
#
# Total expenses: 9000.0
# Remaining budget: -2000.0
# ⚠ Warning: Your budget is negative! You are overspending.

# %% [markdown]
# ### 🐛 Debugging and Refinement

# %%
# Document any issues and fixes
issues_found = [
    "Issue 1: [Describe the problem]",
    "Fix 1: [How you solved it]",
    # Add more as needed
]

print("🔧 DEBUGGING NOTES:")
for item in issues_found:
    print(f"- {item}")

# %%
# REFINED VERSION - Your Working Budget Tracker
# [Paste your corrected/improved code here]

# %% [markdown]
# ## Part 4: Enhancement Challenge
#
# Choose ONE feature to add using AI assistance:
# - 🏷️ Expense categories (food, transport, entertainment)
# - 📊 Show percentage of income spent
# - ✅ Input validation (no negative numbers)
# - 📝 Detailed budget summary with advice

# %%
# Document your enhancement
enhancement_choice = "I chose to add: percentage of income spent"
enhancement_prompt = """
From the previous python codes, Show percentage of income spent
"""

print(f"🚀 ENHANCEMENT: {enhancement_choice}")
# Out:
# 🚀 ENHANCEMENT: I chose to add: percentage of income spent

# %%
# ENHANCED BUDGET TRACKER
# Ask for monthly income
income = float(input("Enter your monthly income: "))

# Ask for up to 3 expenses
expense1 = float(input("Enter expense 1: "))
expense2 = float(input("Enter expense 2: "))
expense3 = float(input("Enter expense 3: "))

# Calculate total expenses
total_expenses = expense1 + expense2 + expense3

# Calculate remaining budget
remaining_budget = income - total_expenses

# Calculate percentage spent
percentage_spent = (total_expenses / income) * 100

# Display results
print("\nTotal expenses:", total_expenses)
print("Remaining budget:", remaining_budget)
print("Percentage of income spent:", round(percentage_spent, 2), "%")

# Warning if negative
if remaining_budget < 0:
    print("⚠ Warning: Your budget is negative! You are overspending.")
else:
    print("Good job! Your spending is within your budget.")
# Out:
# Enter your monthly income: 10000
# Enter expense 1: 2000
# Enter expense 2: 3000
# Enter expense 3: 4000
#
# Total expenses: 9000.0
# Remaining budget: 1000.0
# Percentage of income spent: 90.0 %
# Good job! Your spending is within your budget.

# %% [markdown]
# ## Part 5: Reflection and Lab Exit Ticket Preparation

# %%
from datetime import datetime

# Final Evidence Package Summary
evidence_2 = {
    "timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    "context": "Creating the full budget tracker with enhancements that display the percentage of income spent",
    "ai_tool_used": "ChatGPT",
    "prompts_used": 3,  # Update this number
    "iterations_needed": 1,  # How many times you refined
    "final_reflection": "AI-assisted programming has helped me enhance my debugging skills that is; Identifying wrong data types and understanding what different error messages mean. "
}

print("📋 EVIDENCE PACKAGE #2 (Final)")
for key, value in evidence_2.items():
    print(f"{key}: {value}")
# Out:
# 📋 EVIDENCE PACKAGE #2 (Final)
# timestamp: 2026-02-25 19:00:59
# context: Creating the full budget tracker with enhancements that display the percentage of income spent
# ai_tool_used: ChatGPT
# prompts_used: 3
# iterations_needed: 1
# final_reflection: AI-assisted programming has helped me enhance my debugging skills that is; Identifying wrong data types and understanding what different error messages mean.

# %% [markdown]
# ## 🎯 Submission Checklist
#
# Before submitting:
# - ✅ All code cells run without errors
# - ✅ You've documented at least 2 AI interactions
# - ✅ Budget tracker accepts income and 3+ expenses
# - ✅ Completed both Evidence Packages
# - ✅ Attempted the enhancement challenge
# - ✅ Reflected on your AI collaboration experience

# %%
# Generate submission summary
print("="*50)
print("WEEK 1 WORKSHEET COMPLETION SUMMARY")
print("="*50)
print(f"Student Name: Nancy Eugene")
print(f"Completion Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("\nCore Features Implemented:")
print("✅ Basic income/expense input")
print("✅ Budget calculation")
print("✅ Warning for negative budget")
print("✅ Enhancement: Display of percentage of income spent.")
print("\nAI Collaboration Stats:")
print(f"- AI tools used: ChatGPT")
print(f"- Number of prompts: 3")
print(f"- Success rate: 95%")
print("\n🎉 Ready for Lab Exit Ticket submission!")
# Out:
# ==================================================
# WEEK 1 WORKSHEET COMPLETION SUMMARY
# ==================================================
# Student Name: Nancy Eugene
# Completion Time: 2026-02-25 16:42:44
#
# Core Features Implemented:
# ✅ Basic income/expense input
# ✅ Budget calculation
# ✅ Warning for negative budget
# ✅ Enhancement: Display of percentage of income spent.
#
# AI Collaboration Stats:
# - AI tools used: ChatGPT
# - Number of prompts: 3
# - Success rate: 95%
#
# 🎉 Ready for Lab Exit Ticket submission!

# %% [markdown]
# ## 💭 Final Reflection Questions
#
# **1. What surprised you most about working with AI to generate code?**
# When working with AI to generate codes, I learnt that errors can be learning points that is, with AI I can know the specific error and obtain feedback on how to fix it so that the written codes can run smoothly.
#
# **2. What makes a good prompt vs. a poor prompt?**
# A good prompt is typically made of a clear description of the specific problem with its requirements such as the programming language, inputs to be entered, calculations or logical processes and outputs to be displayed.
# On the other hand, a poor prompt usually contains a vague description and specification of the programming language, problem, goal and intended output which often results to irrelevant/incorrect codes.
#
# **3. How do you see AI tools fitting into your future programming workflow?**
# As humanbeings describe their problems in written descriptions, AI tools help to define the structure and algorithms of their codes into technical requirements. AI tools review existing codes to simplify them, erase duplicates and improving their performance by providing guided improvements on code errors.
#
# ---
#
# ### 📁 Save and Next Steps:
# 1. File > Save a copy in GitHub (if you haven't already)
# 2. Prepare evidence for next lab session for the Exit Ticket
# 3. Start thinking about Week 2: Variables & Data Types!
