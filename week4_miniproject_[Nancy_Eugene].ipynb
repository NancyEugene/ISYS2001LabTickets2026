# %% [markdown]
# <a href="https://colab.research.google.com/github/NancyEugene/ISYS2001LabTickets2026/blob/main/week4_miniproject_%5BNancy_Eugene%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 4 Mini-Project: Loop-Powered Finance Tracker
# ## Adding Repetition to Your Financial Decision System
#
# **Duration:** 45-60 minutes
# **Goal:** Apply this week's loop patterns to enhance your Week 2 finance tracker
#
# ### Project Overview
#
# Take your Week 2 single-decision finance tracker and add **loop power**:
# - 🔄 Handle multiple expense entries in one session
# - ✅ Validate all user input properly
# - 📊 Calculate running totals and basic statistics
# - 🎯 Track multiple savings goals
# - 🎮 Create a simple menu system
#
# This builds the **data collection foundation** for your semester-long finance tracker project.
#
# ### Learning Objectives
#
# - Apply while loops for input validation
# - Use for loops for known repetition
# - Implement sentinel value patterns
# - Practice list storage and basic processing
# - Build user-controlled program flow
#
# ---

# %% [markdown]
# ## Part 1: Enhanced Expense Entry (15 minutes)
#
# ### 🔄 From One to Many
#
# Transform your Week 2 single-expense tracker to handle multiple expenses with proper validation:

# %%
print("=== Enhanced Finance Tracker v0.3 ===")
print("Week 3: Loop-Powered Edition")
print()

# User setup (enhanced from Week 2)
name = input("Enter your name: ")

# Add budget validation using while loop
monthly_budget = 0
while monthly_budget < 100 or monthly_budget > 10000:
    try:
        budget_input = input("Enter monthly budget ($100-$10,000): $")
        monthly_budget = float(budget_input)

        if monthly_budget < 100:
            print("Budget too low! Minimum $100")
        elif monthly_budget > 10000:
            print("Budget seems high! Maximum $10,000")
    except ValueError:
        print("Please enter a valid number!")

print(f"\nWelcome {name}! Monthly budget: ${monthly_budget:.2f}")

# ========== MULTI-EXPENSE ENTRY ==========
expenses = []  # Store all expense amounts
descriptions = []  # Store what each expense was for
total_spent = 0

print("\n--- Enter Your Expenses ---")
print("Type 'done' when finished entering expenses")

# Your task: Complete the multi-expense entry system
# Use sentinel value pattern to collect multiple expenses
# Validate each expense amount (positive numbers only)
# Store both amount and description
# Show running total and budget percentage after each entry

while True:
    expense_input = input("\nExpense amount (or 'done'): $")

    if expense_input.lower() == 'done':
        break

    # Your validation and storage code here
    try:
        expense_amount = float(expense_input)
        if expense_amount <= 0:
            print("Expense must be a positive number!")
            continue

        description = input("Enter expense description: ")
        expenses.append(expense_amount)
        descriptions.append(description)
        total_spent += expense_amount

        print(f"Current total spent: ${total_spent:.2f}")
        if monthly_budget > 0:
            budget_percentage = (total_spent / monthly_budget) * 100
            print(f"Budget used: {budget_percentage:.1f}%")

    except ValueError:
        print("Invalid input! Please enter a valid number for the expense.")


print(f"\n📊 Expense entry complete: {len(expenses)} expenses, ${total_spent:.2f} total")
# Out:
# === Enhanced Finance Tracker v0.3 ===
# Week 3: Loop-Powered Edition
#
# Enter your name: Nancy
# Enter monthly budget ($100-$10,000): $7500
#
# Welcome Nancy! Monthly budget: $7500.00
#
# --- Enter Your Expenses ---
# Type 'done' when finished entering expenses
#
# Expense amount (or 'done'): $450
# Enter expense description: food
# Current total spent: $450.00
# Budget used: 6.0%
#
# Expense amount (or 'done'): $clothes
# Invalid input! Please enter a valid number for the expense.
#
# Expense amount (or 'done'): $800
# Enter expense description: clothes
# Current total spent: $1250.00
# Budget used: 16.7%
#
# Expense amount (or 'done'): $done
#
# 📊 Expense entry complete: 2 expenses, $1250.00 total

# %% [markdown]
# ---
#
# ## Part 2: Basic Expense Analysis (15 minutes)
#
# ### 📈 Processing Your Transaction Data
#
# Use loops to analyze the expenses you collected:

# %%
# Expense Analysis Section
if len(expenses) > 0:
    print("\n📊 Expense Analysis:")

    # Basic statistics using loop patterns from workshops
    print(f"Total expenses: {len(expenses)}")
    print(f"Total spent: ${total_spent:.2f}")
    print(f"Average expense: ${total_spent/len(expenses):.2f}")
    print(f"Budget used: {(total_spent/monthly_budget)*100:.1f}%")
    print(f"Remaining budget: ${monthly_budget - total_spent:.2f}")

    # Your task: Find highest and lowest expenses
    # Use the min/max pattern from workshops
    highest_expense = 0
    lowest_expense = 0

    # Your min/max finding code here
    for expense in expenses:
        if expense > highest_expense:
            highest_expense = expense

        if expense < lowest_expense:
            lowest_expense = expense

    print(f"\n💰 Expense Range:")
    print(f"Highest expense: ${highest_expense:.2f}")
    print(f"Lowest expense: ${lowest_expense:.2f}")

    # Your task: Categorize expenses by size
    # Count how many expenses fall into each category:
    # Large (>20% of budget), Medium (5-20%), Small (<5%)

    large_count = 0    # > 20% of budget
    medium_count = 0   # 5-20% of budget
    small_count = 0    # < 5% of budget

    # Your categorization loop here
    for expense in expenses:
        percentage = (expense / monthly_budget) * 100

        if percentage > 20:
            large_count += 1
        elif percentage >= 5:
            medium_count += 1
        else:
            small_count += 1

    print(f"\n📊 Expense Categories:")
    print(f"Large expenses (>20% budget): {large_count}")
    print(f"Medium expenses (5-20% budget): {medium_count}")
    print(f"Small expenses (<5% budget): {small_count}")

    # Your task: Provide smart feedback based on the analysis
    # Give different advice based on spending patterns
    print("\n💡 Smart Feedback:")

    # Your feedback logic here
    # Consider: budget percentage used, number of large expenses, etc.
    if total_spent > monthly_budget:
        print("You have exceeded your budget!")
    elif total_spent > monthly_budget * 0.8:
        print("You are close to your budget limit. Be careful!")
    else:
        print("Your spending is within a safe range.")

    if large_count > 2:
        print("You have many large expenses. Try reducing big purchases.")

    if small_count > large_count:
        print("Good job! Most of your expenses are small and manageable.")

else:
    print("\n📝 No expenses entered - try adding some transactions!")
# Out:
# 📊 Expense Analysis:
# Total expenses: 2
# Total spent: $2350.00
# Average expense: $1175.00
# Budget used: 31.3%
# Remaining budget: $5150.00
#
# 💰 Expense Range:
# Highest expense: $2000.00
# Lowest expense: $0.00
#
# 📊 Expense Categories:
# Large expenses (>20% budget): 1
# Medium expenses (5-20% budget): 0
# Small expenses (<5% budget): 1
#
# 💡 Smart Feedback:
# Your spending is within a safe range.

# %% [markdown]
# ---
#
# ## Part 3: Multiple Savings Goals Tracker (15 minutes)
#
# ### 🎯 Goal Management with Loops
#
# Extend your tracker to handle multiple savings goals:

# %%
print("\n=== Savings Goals Tracker ===")

# Goal collection
goal_names = []
goal_targets = []
goal_current = []

# Ask how many goals they want to track
num_goals = 0
while num_goals < 1 or num_goals > 5:  # Reasonable limits
    try:
        num_goals = int(input("How many savings goals? (1-5): "))
        if num_goals < 1:
            print("Must have at least 1 goal!")
        elif num_goals > 5:
            print("Maximum 5 goals for this tracker!")
    except ValueError:
        print("Please enter a valid number!")

# Your task: Collect goal information using for loop
# For each goal (1 to num_goals):
#   - Get goal name
#   - Get target amount (with validation)
#   - Get current amount (with validation)
#   - Store in the three lists

print(f"\nEntering {num_goals} savings goals:")

for i in range(num_goals):
    print(f"\n--- Goal {i+1} ---")

    # Your goal collection code here
        # Get goal name
    name = input("Enter goal name: ")
    goal_names.append(name)

    # Get target amount (must be positive)
    target = -1
    while target <= 0:
        try:
            target = float(input("Enter target amount: $"))
            if target <= 0:
                print("Target must be greater than 0!")
        except ValueError:
            print("Please enter a valid number!")
    goal_targets.append(target)

    # Get current amount (must be between 0 and target)
    current = -1
    while current < 0 or current > target:
        try:
            current = float(input("Enter current savings: $"))
            if current < 0:
                print("Current amount cannot be negative!")
            elif current > target:
                print("Current amount cannot exceed target!")
        except ValueError:
            print("Please enter a valid number!")
    goal_current.append(current)


print(f"\n✅ Saved {len(goal_names)} goals!")
# Out:
# === Savings Goals Tracker ===
# How many savings goals? (1-5): 3
#
# Entering 3 savings goals:
#
# --- Goal 1 ---
# Enter goal name: food
# Enter target amount: $4000
# Enter current savings: $2000
#
# --- Goal 2 ---
# Enter goal name: clothes
# Enter target amount: $5000
# Enter current savings: $3560
#
# --- Goal 3 ---
# Enter goal name: bags
# Enter target amount: $5750
# Enter current savings: $4575
#
# ✅ Saved 3 goals!

# %%
# Goal Analysis and Progress Tracking
if len(goal_names) > 0:
    print("\n📊 Goals Progress Analysis:")

    # Initialize variables for overall summary
    target_overall = 0
    current_overall = 0

    # Initialize variables for finding the goal needing most attention
    lowest_progress = 101.0
    attention_goal = ""

    for i in range(len(goal_names)):
        goal_name = goal_names[i]
        goal_target = goal_targets[i]
        goal_current_amount = goal_current[i]

        # Calculate individual goal analysis
        # Progress percentage
        progress = (goal_current_amount / goal_target) * 100 if goal_target > 0 else 0
        # Amount remaining
        goal_remaining = goal_target - goal_current_amount
        # Months to completion (if saving $100/month), handle non-positive remaining
        goal_months_to_completion = goal_remaining / 100 if goal_remaining > 0 else 0

        print(f"\n--- {goal_name} ---")
        print(f"  Target: ${goal_target:.2f}")
        print(f"  Saved: ${goal_current_amount:.2f}")
        print(f"  Progress: {progress:.1f}%")
        print(f"  Remaining: ${goal_remaining:.2f}")
        print(f"  Months to complete (at $100/month): {goal_months_to_completion:.1f}")

        # Accumulate for overall summary
        target_overall += goal_target
        current_overall += goal_current_amount

        # Track lowest progress goal
        if progress < lowest_progress:
            lowest_progress = progress
            attention_goal = goal_name

    # Overall progress summary
    overall_progress = (current_overall / target_overall) * 100 if target_overall > 0 else 0
    overall_remaining = target_overall - current_overall
    overall_months = overall_remaining / 100 if overall_remaining > 0 else 0

    print(f"\n🎯 Overall Goals Summary:")
    print(f"Total target: ${target_overall:.2f}")
    print(f"Total saved: ${current_overall:.2f}")
    print(f"Overall progress: {overall_progress:.1f}%")
    print(f"Total remaining: ${overall_remaining:.2f}")
    print(f"Overall months to complete (at $100/month): {overall_months:.1f}")

    # Display goal needing most attention
    print(f"\n Goal Needing Most Attention:")
    if attention_goal:
        print(f"{attention_goal} ({lowest_progress:.1f}% complete)")

        if lowest_progress < 25:
            print("You're just getting started. Try increasing your monthly savings!")
        elif lowest_progress < 50:
            print("Good progress, but stay consistent!")
        else:
            print("You're making great progress on this goal!")
    else:
        print("No specific goal identified for attention (this should not happen if goals exist).")

else:
    print("No goals to analyze!")
# Out:
# 📊 Goals Progress Analysis:
#
# --- food ---
#   Target: $4500.00
#   Saved: $3450.00
#   Progress: 76.7%
#   Remaining: $1050.00
#   Months to complete (at $100/month): 10.5
#
# --- bags ---
#   Target: $5000.00
#   Saved: $550.00
#   Progress: 11.0%
#   Remaining: $4450.00
#   Months to complete (at $100/month): 44.5
#
# --- shoes ---
#   Target: $6000.00
#   Saved: $450.00
#   Progress: 7.5%
#   Remaining: $5550.00
#   Months to complete (at $100/month): 55.5
#
# 🎯 Overall Goals Summary:
# Total target: $15500.00
# Total saved: $4450.00
# Overall progress: 28.7%
# Total remaining: $11050.00
# Overall months to complete (at $100/month): 110.5
#
#  Goal Needing Most Attention:
# shoes (7.5% complete)
# You're just getting started. Try increasing your monthly savings!

# %% [markdown]
# ---
#
# ## Part 4: Simple Menu System (10 minutes)
#
# ### 🎮 Interactive Program Flow
#
# Create a basic menu that lets users choose what to do:

# %%
print("\n=== Interactive Finance Menu ===")

# Simple menu system
running = True
name = input("Enter your name: ")
while running:
    print("\n" + "-"*30)
    print(f"💰 {name}'s Finance Tracker")
    if len(expenses) > 0:
        print(f"📊 Current: {len(expenses)} expenses, ${sum(expenses):.2f} spent")
    print("-"*30)
    print("1. View expense summary")
    print("2. View goals progress")
    print("3. Add new expense")
    print("4. Budget check")
    print("5. Exit")

    choice = input("\nChoose option (1-5): ")

    if choice == "1":
        # Display expense summary
        print("\n--- Expense Summary ---")

        # Your task: Show all expenses with numbers
        # Format: "1. $23.50 - Coffee"
        # Include total at the end
        total = 0

        for i in range(len(expenses)):
            print(f"{i+1}. ${expenses[i]:.2f}")
            total += expenses[i]

        print(f"Total: ${total:.2f}")


    elif choice == "2":
        # Display goals progress
        print("\n--- Goals Progress ---")

        # Your task: Show each goal with progress percentage
        # Format: "Goal Name: $current/$target (XX% complete)"
        for i in range(len(goal_names)):
            progress = (goal_current[i] / goal_targets[i]) * 100
            print(f"{goal_names[i]}: ${goal_current[i]}/{goal_targets[i]} ({progress:.1f}% complete)")

    elif choice == "3":
        # Add single new expense
        print("\n--- Add New Expense ---")

        # Your task: Add one more expense to existing lists
        # Use validation pattern, update totals, give feedback
        while True:
            try:
                new_expense = float(input("Enter expense amount: $"))
                if new_expense > 0:
                    expenses.append(new_expense)
                    print("Expense added!")
                    break
                else:
                    print("Enter a positive number!")
            except ValueError:
                print("Invalid input!")

    elif choice == "4":
        # Budget status check
        print("\n--- Budget Check ---")

        # Your task: Calculate and display budget status
        # Show percentage used, remaining amount, daily budget left
        # Give advice based on budget usage
        total = sum(expenses)
        percent = (total / monthly_budget) * 100
        remaining = monthly_budget - total
        daily_left = remaining / 30

        print(f"Budget used: {percent:.1f}%")
        print(f"Remaining: ${remaining:.2f}")
        print(f"Daily budget left: ${daily_left:.2f}")

        if percent > 100:
            print("Over budget!")
        elif percent > 80:
            print("Close to limit!")
        else:
            print("Budget is okay.")

    elif choice == "5":
        # Exit with summary
        running = False
        print(f"\nGoodbye {name}!")
        print(f"Final summary: {len(expenses)} expenses, ${sum(expenses) if expenses else 0:.2f} total")
        print("🚀 Your finance tracker is growing stronger each week!")

    else:
        print("Invalid choice! Please choose 1-5.")

print("\n=== Finance Tracker Session Complete ===")
# Out:
# === Interactive Finance Menu ===
# Enter your name: Nancy
#
# ------------------------------
# 💰 Nancy's Finance Tracker
# 📊 Current: 2 expenses, $2350.00 spent
# ------------------------------
# 1. View expense summary
# 2. View goals progress
# 3. Add new expense
# 4. Budget check
# 5. Exit
#
# Choose option (1-5): 1
#
# --- Expense Summary ---
# 1. $350.00
# 2. $2000.00
# Total: $2350.00
#
# ------------------------------
# 💰 Nancy's Finance Tracker
# 📊 Current: 2 expenses, $2350.00 spent
# ------------------------------
# 1. View expense summary
# 2. View goals progress
# 3. Add new expense
# 4. Budget check
# 5. Exit
#
# Choose option (1-5): 4
#
# --- Budget Check ---
# Budget used: 31.3%
# Remaining: $5150.00
# Daily budget left: $171.67
# Budget is okay.
#
# ------------------------------
# 💰 Nancy's Finance Tracker
# 📊 Current: 2 expenses, $2350.00 spent
# ------------------------------
# 1. View expense summary
# 2. View goals progress
# 3. Add new expense
# 4. Budget check
# 5. Exit
#
# Choose option (1-5): 5
#
# Goodbye Nancy!
# Final summary: 2 expenses, $2350.00 total
# 🚀 Your finance tracker is growing stronger each week!
#
# === Finance Tracker Session Complete ===

# %% [markdown]
# ---
#
# ## Part 5: Testing Your Enhanced Tracker (10 minutes)
#
# ### 🧪 Complete System Test
#
# Test your loop-powered finance tracker with realistic data:

# %%
# Test your tracker with this scenario:
test_instructions = """
🧪 TEST SCENARIO:

Setup:
- Name: Your name
- Budget: $2000

Goals (try 2 goals):
- "Emergency Fund": target $1000, current $250
- "Vacation": target $500, current $50

Expenses to enter:
- $450 for "Rent payment"
- $67.50 for "Weekly groceries"
- $89.00 for "Gas for car"
- done

Then test each menu option:
1. View expense summary (should show 3 expenses)
2. View goals progress (should show percentages)
3. Add expense: $25 for "Coffee"
4. Budget check (should show updated totals)
5. Exit

Expected final result:
- 4 expenses totaling $631.50
- 31.6% of budget used
- Emergency fund 25% complete
- Vacation fund 10% complete
"""

print(test_instructions)
print("\n⬆️ Run your enhanced tracker above with this test data!")
print("Check that all numbers match the expected results.")
# Out:
# 🧪 TEST SCENARIO:
#
# Setup:
# - Name: Your name
# - Budget: $2000
#
# Goals (try 2 goals):
# - "Emergency Fund": target $1000, current $250
# - "Vacation": target $500, current $50
#
# Expenses to enter:
# - $450 for "Rent payment"
# - $67.50 for "Weekly groceries"
# - $89.00 for "Gas for car"
# - done
#
# Then test each menu option:
# 1. View expense summary (should show 3 expenses)
# 2. View goals progress (should show percentages)
# 3. Add expense: $25 for "Coffee"
# 4. Budget check (should show updated totals)
# 5. Exit
#
# Expected final result:
# - 4 expenses totaling $631.50
# - 31.6% of budget used
# - Emergency fund 25% complete
# - Vacation fund 10% complete
#
#
# ⬆️ Run your enhanced tracker above with this test data!
# Check that all numbers match the expected results.

# %%
name = input("Enter your name: ")
print(f"Welcome {name}!")

budget = float(input("Enter your monthly budget: $"))
print(f"Your budget is ${budget:.2f}")

# Goals
goal_names = []
goal_targets = []
goal_current = []

num_goals = int(input("How many goals?: "))
print(f"\nEntering {num_goals} savings goals:")

for i in range(num_goals):
    print(f"\n--- Goal {i+1} ---")


    goal_name_input = input("Enter goal name: ")
    goal_names.append(goal_name_input)

    target = -1
    while target <= 0:
        try:
            target = float(input("Enter target amount: $"))
            if target <= 0:
                print("Target must be greater than 0!")
        except ValueError:
            print("Please enter a valid number!")
    goal_targets.append(target)

    current = -1
    while current < 0 or current > target:
        try:
            current = float(input("Enter current savings: $"))
            if current < 0:
                print("Current amount cannot be negative!")
            elif current > target:
                print("Current amount cannot exceed target!")
        except ValueError:
            print("Please enter a valid number!")
    goal_current.append(current)

# Expenses
print("\n--- Enter Expenses ---")
expenses = []
descriptions = []
total_spent = 0

while True:
    expense_input = input("\nExpense amount (or 'done'): $")

    if expense_input.lower() == 'done':
        break

    try:
        expense_amount = float(expense_input)
        if expense_amount <= 0:
            print("Expense must be a positive number!")
            continue

        description = input("Enter expense description: ")
        expenses.append(expense_amount)
        descriptions.append(description)
        total_spent += expense_amount

    except ValueError:
        print("Invalid input! Please enter a valid number for the expense.")

# Expense Summary
total = 0

print("\n--- Expense Summary ---")
if len(expenses) > 0:
  for i in range(len(expenses)):
    total += expenses[i]
    print(f"{i+1}. ${expenses[i]:.2f} - {descriptions[i]}")

print(f"Total: ${total_spent:.2f}")

# Goal progress
print("\n--- Goals Progress ---")

for i in range(len(goal_names)):
    progress = (goal_current[i] / goal_targets[i]) * 100
    print(f"{goal_names[i]}: ${goal_current[i]}/{goal_targets[i]} ({progress:.1f}%)")

# Additional expense
print("\n--- Adding Extra Expense ---")
expenses.append(25)
descriptions.append("Coffee")
total_spent += 25

print("Added: $25 - Coffee")
print(f"New total: ${total_spent:.2f}")

# Budget Check
print("\n--- Budget Check ---")
percent = (total_spent / budget) * 100
remaining = budget - total_spent

print(f"Budget used: {percent:.1f}%")
print(f"Remaining: ${remaining:.2f}")



print(f"\nTotal expenses entered: {len(expenses)}")
print(f"Total amount spent: ${total_spent:.2f}")
# Out:
# Enter your name: Nancy
# Welcome Nancy!
# Enter your monthly budget: $2000
# Your budget is $2000.00
# How many goals?: 2
#
# Entering 2 savings goals:
#
# --- Goal 1 ---
# Enter goal name: Emergency fund
# Enter target amount: $1000
# Enter current savings: $250
#
# --- Goal 2 ---
# Enter goal name: Vacation
# Enter target amount: $500
# Enter current savings: $50
#
# --- Enter Expenses ---
#
# Expense amount (or 'done'): $450
# Enter expense description: Rent payment
#
# Expense amount (or 'done'): $67.50
# Enter expense description: Weekly Groceries
#
# Expense amount (or 'done'): $89.00
# Enter expense description: Gas for car
#
# Expense amount (or 'done'): $done
#
# --- Expense Summary ---
# 1. $450.00 - Rent payment
# 2. $67.50 - Weekly Groceries
# 3. $89.00 - Gas for car
# Total: $606.50
#
# --- Goals Progress ---
# Emergency fund: $250.0/1000.0 (25.0%)
# Vacation: $50.0/500.0 (10.0%)
#
# --- Adding Extra Expense ---
# Added: $25 - Coffee
# New total: $631.50
#
# --- Budget Check ---
# Budget used: 31.6%
# Remaining: $1368.50
#
# Total expenses entered: 4
# Total amount spent: $631.50

# %%
print("=== TEST MODE ===")

# Setup (instead of input)
name = "Nancy"
monthly_budget = 2000

# Goals
goal_names = ["Emergency Fund", "Vacation"]
goal_targets = [1000, 500]
goal_current = [250, 50]

# Expenses
expenses = [450, 67.50, 89]
descriptions = ["Rent payment", "Weekly groceries", "Gas for car"]

# Calculate total
total_spent = sum(expenses)

print(f"\nWelcome {name}! Budget: ${monthly_budget}")

print("\n--- Expenses Entered ---")
for i in range(len(expenses)):
    print(f"{i+1}. ${expenses[i]:.2f} - {descriptions[i]}")

print(f"Total: ${total_spent:.2f}")

print("\n--- Goals Progress ---")
for i in range(len(goal_names)):
    progress = (goal_current[i] / goal_targets[i]) * 100
    print(f"{goal_names[i]}: ${goal_current[i]}/{goal_targets[i]} ({progress:.1f}%)")

print("\n--- Adding Extra Expense ---")
expenses.append(25)
descriptions.append("Coffee")
total_spent += 25

print(f"New total: ${total_spent:.2f}")

print("\n--- Budget Check ---")
percent = (total_spent / monthly_budget) * 100
print(f"Budget used: {percent:.1f}%")
# Out:
# === TEST MODE ===
#
# Welcome Nancy! Budget: $2000
#
# --- Expenses Entered ---
# 1. $450.00 - Rent payment
# 2. $67.50 - Weekly groceries
# 3. $89.00 - Gas for car
# Total: $606.50
#
# --- Goals Progress ---
# Emergency Fund: $250/1000 (25.0%)
# Vacation: $50/500 (10.0%)
#
# --- Adding Extra Expense ---
# New total: $631.50
#
# --- Budget Check ---
# Budget used: 31.6%

# %% [markdown]
# ---
#
# ## Part 6: Reflection and Planning (10 minutes)
#
# ### 🤔 What You've Accomplished
#
# Reflect on your computational thinking growth this week:

# %%
# Week 3 Reflection Questions (answer as comments)

# LOOP PATTERN MASTERY:
# Which loop patterns did you use in your finance tracker?
# When did you choose while vs for?
# For my finance tracker I used the for loop and the while loop. The "for loop" was used for counted repititions such as displaying the expenses or saving goals as per the number of items the user decides to input. The "while loop" was used for conditional repitition like setting target amounts to be greater than zero or conditioning the current amount to be less than the target amount.

# PROBLEM SOLVING:
# How did you break down the "multiple expenses" problem?
# What was most challenging about validation loops?
# I broke down the "multiple expenses" problem by establishing a loop which could ask for the user's expenses (description and amounts) on repeat which could theafter be broken after the user types the word "done". The input had to be valid that is, in positive numbers and not otherwise (in letters/negative numbers), it was stored in lists and the total was constantly updated.
# The most challenging part about validation loops was making sure the loop stops with the right words and the right time and setting the valid inputs for whatever the user will type.

# DATA PROCESSING:
# How does storing expenses in lists change what your tracker can do?
# What analysis became possible that wasn't before?
# Storing expenses in lists changes what my tracker can do by storing, accessing and processing the entered expenses at once, this therefore easens the process of making further manipulation of the data such as calculation of totals, averages, percentages, minimum and maximum values.
# Analysis that became possible is such as determination of the total expenses, categorizing expenses and determining the largest and smallest expenses.

# AI PARTNERSHIP:
# How did you use AI to help with loop problems this week?
# What questions led to the best learning?
# I used AI to check if the flow of my code made sense, I asked it to interpret the lines of code i did not understand quite well and i asked it to give me alternative means of displaying the same output in a simpler way as seen in part 5 above.
# Questions that led to the best learning were the ones that focused on explaing the logic of things rather than simply just getting answers, for instance: "Why shouldn't the current amount not be greater than the target amount?" or "Why isn't my loop stopping even when I type sentinel value?"

# FUTURE FEATURES:
# What financial features would you want to add next?
# How might AI enhance your tracker in future weeks?
# The financial features I would want to add next are such as the charts that show the proportion of income spent on each item.
# AI might enhance my tracker in future weeks by being a financial advisor by giving personalised recommendation as per my expenses, predict future spending trends, and automatically categorise expenses.

print("🎯 Week 3 reflection complete!")
print("Ready for Week 4: String processing and smart categorization!")

# %% [markdown]
# ---
#
# ## 🏆 Mini-Project Complete!
#
# ### **What You've Built:**
# Enhanced your finance tracker with **loop-powered capabilities**:
#
# ✅ **Multi-Transaction Entry**: Handle multiple expenses in one session
# ✅ **Smart Validation**: Robust input checking with helpful error messages
# ✅ **Data Storage**: Transaction history saved in lists for analysis
# ✅ **Basic Analysis**: Statistics, categorization, and insights
# ✅ **Goal Tracking**: Multiple savings goals with progress monitoring
# ✅ **Interactive Menus**: User-controlled program flow
#
# ### **Programming Skills Mastered:**
# - **While loops** for input validation and unknown repetition
# - **For loops** for known counts and collection processing
# - **Sentinel values** for user-controlled data entry
# - **List operations** for data storage and retrieval
# - **Menu systems** for interactive programs
#
# ### **Computational Thinking Growth:**
# - **Pattern Recognition**: Identifying when repetition is needed
# - **Decomposition**: Breaking complex features into loop patterns
# - **Abstraction**: Reusable validation and analysis patterns
# - **Algorithm Design**: Planning loop logic before implementation
#
# ### **Finance Tracker Evolution:**
# - **Week 1**: Basic calculations
# - **Week 2**: Smart decisions with if/elif/else
# - **Week 3**: **Loop-powered data collection and analysis**
# - **Week 4 Preview**: String processing for automatic categorization
#
# ### **🚀 Next Week Preview:**
# Week 4 will add **string manipulation** to your tracker:
# - Automatically categorize expenses by description
# - Parse and clean transaction text
# - Smart search through transaction descriptions
# - Prepare for natural language processing
#
# ### **🎯 Success Check:**
# You're successful if:
# - Your tracker handles multiple transactions smoothly
# - You understand when to use each loop type
# - Your validation prevents crashes from bad input
# - You can explain your loop choices to others
# - You're excited about adding string processing next week
#
# ### **💾 Save Your Work!**
# Your loop-powered tracker is the foundation for Week 4's string processing features. Keep building this same project each week!
#
# ---
#
# **🌟 Excellent work! You've transformed your finance tracker from a simple calculator into a data-driven analysis tool. Next week we'll make it even smarter with text processing! 💰🔄**
